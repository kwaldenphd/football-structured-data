# %% [markdown]
# # Scrape Combined ND Football Schedules From Sports Reference
#
#
#
# # Load Modules Using Import

# %%
# import requests
import requests

# import csv
import csv

# import beautifulsoup
from bs4 import BeautifulSoup
from bs4 import Comment

# import pandas
import pandas as pd

# import numpy
import numpy as np

# %% [markdown]
# # Get List of Season URLs from Sports Reference

# %%
# root url
root = "https://www.sports-reference.com/cfb/schools/notre-dame/"

# year range
years = range(1899, 2021, 1)

# url tag
tag = "-schedule.html"

# empty list for urls
urls = []

# for loop that concatenates full url
for year in years:
    urls.append(root + str(year) + tag)
    
# show sample url
urls[0]
# Out:
# 'https://www.sports-reference.com/cfb/schools/notre-dame/1899-schedule.html'

# %% [markdown]
# # Create Dictionary That Connects Season Year With URL

# %%
test_dict = {years[i]: urls[i] for i in range(len(years))}

test_dict
# Out:
# {1899: 'https://www.sports-reference.com/cfb/schools/notre-dame/1899-schedule.html',
#  1900: 'https://www.sports-reference.com/cfb/schools/notre-dame/1900-schedule.html',
#  1901: 'https://www.sports-reference.com/cfb/schools/notre-dame/1901-schedule.html',
#  1902: 'https://www.sports-reference.com/cfb/schools/notre-dame/1902-schedule.html',
#  1903: 'https://www.sports-reference.com/cfb/schools/notre-dame/1903-schedule.html',
#  1904: 'https://www.sports-reference.com/cfb/schools/notre-dame/1904-schedule.html',
#  1905: 'https://www.sports-reference.com/cfb/schools/notre-dame/1905-schedule.html',
#  1906: 'https://www.sports-reference.com/cfb/schools/notre-dame/1906-schedule.html',
#  1907: 'https://www.sports-reference.com/cfb/schools/notre-dame/1907-schedule.html',
#  1908: 'https://www.sports-reference.com/cfb/schools/notre-dame/1908-schedule.html',
#  1909: 'https://www.sports-reference.com/cfb/schools/notre-dame/1909-schedule.html',
#  1910: 'https://www.sports-reference.com/cfb/schools/notre-dame/1910-schedule.html',
#  1911: 'https://www.sports-reference.com/cfb/schools/notre-dame/1911-schedule.html',
#  1912: 'https://www.sports-reference.com/cfb/schools/notre-dame/1912-schedule.html',
#  1913: 'https://www.sports-reference.com/cfb/schools/notre-dame/1913-schedule.html',
#  1914: 'https://www.sports-reference.com/cfb/schools/notre-dame/1914-schedule.html',
#  1915: 'https://www.sports-reference.com/cfb/schools/notre-dame/1915-schedule.html',
#  1916: 'https://www.sports-reference.com/cfb/schools/notre-dame/1916-schedule.html',
#  1917: 'https://www.sports-reference.com/cfb/schools/notre-dame/1917-schedule.html',
#  1918: 'https://www.sports-reference.com/cfb/schools/notre-dame/1918-schedule.html',
#  1919: 'https://www.sports-reference.com/cfb/schools/notre-dame/1919-schedule.html',
#  1920: 'https://www.sports-reference.com/cfb/schools/notre-dame/1920-schedule.html',
#  1921: 'https://www.sports-reference.com/cfb/schools/notre-dame/1921-schedule.html',
#  1922: 'https://www.sports-reference.com/cfb/schools/notre-dame/1922-schedule.html',
#  1923: 'https://www.sports-reference.com/cfb/schools/notre-dame/1923-schedule.html',
#  1924: 'https://www.sports-reference.com/cfb/schools/notre-dame/1924-schedule.html',
#  1925: 'https://www.sports-reference.com/cfb/schools/notre-dame/1925-schedule.html',
#  1926: 'https://www.sports-reference.com/cfb/schools/notre-dame/1926-schedule.html',
#  1927: 'https://www.sports-reference.com/cfb/schools/notre-dame/1927-schedule.html',
#  1928: 'https://www.sports-reference.com/cfb/schools/notre-dame/1928-schedule.html',
#  1929: 'https://www.sports-reference.com/cfb/schools/notre-dame/1929-schedule.html',
#  1930: 'https://www.sports-reference.com/cfb/schools/notre-dame/1930-schedule.html',
#  1931: 'https://www.sports-reference.com/cfb/schools/notre-dame/1931-schedule.html',
#  1932: 'https://www.sports-reference.com/cfb/schools/notre-dame/1932-schedule.html',
#  1933: 'https://www.sports-reference.com/cfb/schools/notre-dame/1933-schedule.html',
#  1934: 'https://www.sports-reference.com/cfb/schools/notre-dame/1934-schedule.html',
#  1935: 'https://www.sports-reference.com/cfb/schools/notre-dame/1935-schedule.html',
#  1936: 'https://www.sports-reference.com/cfb/schools/notre-dame/1936-schedule.html',
#  1937: 'https://www.sports-reference.com/cfb/schools/notre-dame/1937-schedule.html',
#  1938: 'https://www.sports-reference.com/cfb/schools/notre-dame/1938-schedule.html',
#  1939: 'https://www.sports-reference.com/cfb/schools/notre-dame/1939-schedule.html',
#  1940: 'https://www.sports-reference.com/cfb/schools/notre-dame/1940-schedule.html',
#  1941: 'https://www.sports-reference.com/cfb/schools/notre-dame/1941-schedule.html',
#  1942: 'https://www.sports-reference.com/cfb/schools/notre-dame/1942-schedule.html',
#  1943: 'https://www.sports-reference.com/cfb/schools/notre-dame/1943-schedule.html',
#  1944: 'https://www.sports-reference.com/cfb/schools/notre-dame/1944-schedule.html',
#  1945: 'https://www.sports-reference.com/cfb/schools/notre-dame/1945-schedule.html',
#  1946: 'https://www.sports-reference.com/cfb/schools/notre-dame/1946-schedule.html',
#  1947: 'https://www.sports-reference.com/cfb/schools/notre-dame/1947-schedule.html',
#  1948: 'https://www.sports-reference.com/cfb/schools/notre-dame/1948-schedule.html',
#  1949: 'https://www.sports-reference.com/cfb/schools/notre-dame/1949-schedule.html',
#  1950: 'https://www.sports-reference.com/cfb/schools/notre-dame/1950-schedule.html',
#  1951: 'https://www.sports-reference.com/cfb/schools/notre-dame/1951-schedule.html',
#  1952: 'https://www.sports-reference.com/cfb/schools/notre-dame/1952-schedule.html',
#  1953: 'https://www.sports-reference.com/cfb/schools/notre-dame/1953-schedule.html',
#  1954: 'https://www.sports-reference.com/cfb/schools/notre-dame/1954-schedule.html',
#  1955: 'https://www.sports-reference.com/cfb/schools/notre-dame/1955-schedule.html',
#  1956: 'https://www.sports-reference.com/cfb/schools/notre-dame/1956-schedule.html',
#  1957: 'https://www.sports-reference.com/cfb/schools/notre-dame/1957-schedule.html',
#  1958: 'https://www.sports-reference.com/cfb/schools/notre-dame/1958-schedule.html',
#  1959: 'https://www.sports-reference.com/cfb/schools/notre-dame/1959-schedule.html',
#  1960: 'https://www.sports-reference.com/cfb/schools/notre-dame/1960-schedule.html',
#  1961: 'https://www.sports-reference.com/cfb/schools/notre-dame/1961-schedule.html',
#  1962: 'https://www.sports-reference.com/cfb/schools/notre-dame/1962-schedule.html',
#  1963: 'https://www.sports-reference.com/cfb/schools/notre-dame/1963-schedule.html',
#  1964: 'https://www.sports-reference.com/cfb/schools/notre-dame/1964-schedule.html',
#  1965: 'https://www.sports-reference.com/cfb/schools/notre-dame/1965-schedule.html',
#  1966: 'https://www.sports-reference.com/cfb/schools/notre-dame/1966-schedule.html',
#  1967: 'https://www.sports-reference.com/cfb/schools/notre-dame/1967-schedule.html',
#  1968: 'https://www.sports-reference.com/cfb/schools/notre-dame/1968-schedule.html',
#  1969: 'https://www.sports-reference.com/cfb/schools/notre-dame/1969-schedule.html',
#  1970: 'https://www.sports-reference.com/cfb/schools/notre-dame/1970-schedule.html',
#  1971: 'https://www.sports-reference.com/cfb/schools/notre-dame/1971-schedule.html',
#  1972: 'https://www.sports-reference.com/cfb/schools/notre-dame/1972-schedule.html',
#  1973: 'https://www.sports-reference.com/cfb/schools/notre-dame/1973-schedule.html',
#  1974: 'https://www.sports-reference.com/cfb/schools/notre-dame/1974-schedule.html',
#  1975: 'https://www.sports-reference.com/cfb/schools/notre-dame/1975-schedule.html',
#  1976: 'https://www.sports-reference.com/cfb/schools/notre-dame/1976-schedule.html',
#  1977: 'https://www.sports-reference.com/cfb/schools/notre-dame/1977-schedule.html',
#  1978: 'https://www.sports-reference.com/cfb/schools/notre-dame/1978-schedule.html',
#  1979: 'https://www.sports-reference.com/cfb/schools/notre-dame/1979-schedule.html',
#  1980: 'https://www.sports-reference.com/cfb/schools/notre-dame/1980-schedule.html',
#  1981: 'https://www.sports-reference.com/cfb/schools/notre-dame/1981-schedule.html',
#  1982: 'https://www.sports-reference.com/cfb/schools/notre-dame/1982-schedule.html',
#  1983: 'https://www.sports-reference.com/cfb/schools/notre-dame/1983-schedule.html',
#  1984: 'https://www.sports-reference.com/cfb/schools/notre-dame/1984-schedule.html',
#  1985: 'https://www.sports-reference.com/cfb/schools/notre-dame/1985-schedule.html',
#  1986: 'https://www.sports-reference.com/cfb/schools/notre-dame/1986-schedule.html',
#  1987: 'https://www.sports-reference.com/cfb/schools/notre-dame/1987-schedule.html',
#  1988: 'https://www.sports-reference.com/cfb/schools/notre-dame/1988-schedule.html',
#  1989: 'https://www.sports-reference.com/cfb/schools/notre-dame/1989-schedule.html',
#  1990: 'https://www.sports-reference.com/cfb/schools/notre-dame/1990-schedule.html',
#  1991: 'https://www.sports-reference.com/cfb/schools/notre-dame/1991-schedule.html',
#  1992: 'https://www.sports-reference.com/cfb/schools/notre-dame/1992-schedule.html',
#  1993: 'https://www.sports-reference.com/cfb/schools/notre-dame/1993-schedule.html',
#  1994: 'https://www.sports-reference.com/cfb/schools/notre-dame/1994-schedule.html',
#  1995: 'https://www.sports-reference.com/cfb/schools/notre-dame/1995-schedule.html',
#  1996: 'https://www.sports-reference.com/cfb/schools/notre-dame/1996-schedule.html',
#  1997: 'https://www.sports-reference.com/cfb/schools/notre-dame/1997-schedule.html',
#  1998: 'https://www.sports-reference.com/cfb/schools/notre-dame/1998-schedule.html',
#  1999: 'https://www.sports-reference.com/cfb/schools/notre-dame/1999-schedule.html',
#  2000: 'https://www.sports-reference.com/cfb/schools/notre-dame/2000-schedule.html',
#  2001: 'https://www.sports-reference.com/cfb/schools/notre-dame/2001-schedule.html',
#  2002: 'https://www.sports-reference.com/cfb/schools/notre-dame/2002-schedule.html',
#  2003: 'https://www.sports-reference.com/cfb/schools/notre-dame/2003-schedule.html',
#  2004: 'https://www.sports-reference.com/cfb/schools/notre-dame/2004-schedule.html',
#  2005: 'https://www.sports-reference.com/cfb/schools/notre-dame/2005-schedule.html',
#  2006: 'https://www.sports-reference.com/cfb/schools/notre-dame/2006-schedule.html',
#  2007: 'https://www.sports-reference.com/cfb/schools/notre-dame/2007-schedule.html',
#  2008: 'https://www.sports-reference.com/cfb/schools/notre-dame/2008-schedule.html',
#  2009: 'https://www.sports-reference.com/cfb/schools/notre-dame/2009-schedule.html',
#  2010: 'https://www.sports-reference.com/cfb/schools/notre-dame/2010-schedule.html',
#  2011: 'https://www.sports-reference.com/cfb/schools/notre-dame/2011-schedule.html',
#  2012: 'https://www.sports-reference.com/cfb/schools/notre-dame/2012-schedule.html',
#  2013: 'https://www.sports-reference.com/cfb/schools/notre-dame/2013-schedule.html',
#  2014: 'https://www.sports-reference.com/cfb/schools/notre-dame/2014-schedule.html',
#  2015: 'https://www.sports-reference.com/cfb/schools/notre-dame/2015-schedule.html',
#  2016: 'https://www.sports-reference.com/cfb/schools/notre-dame/2016-schedule.html',
#  2017: 'https://www.sports-reference.com/cfb/schools/notre-dame/2017-schedule.html',
#  2018: 'https://www.sports-reference.com/cfb/schools/notre-dame/2018-schedule.html',
#  2019: 'https://www.sports-reference.com/cfb/schools/notre-dame/2019-schedule.html',
#  2020: 'https://www.sports-reference.com/cfb/schools/notre-dame/2020-schedule.html'}

# %% [markdown]
# # Create Dictionary of Pandas DataFrames with Each Year's Schedule
#
# NOTE: The 1899-1935 seasons do not include an AP poll summary table  before the game information and results. The `if-else` statement in the `for` loop accounts for this varying page table structure.

# %%
# empty dictionary
schedules = {}

# for loop that loads schedule as pandas data frame and saves dataframe as dictionary value associated with season year key
for key, value in test_dict.items():
    df_name = key
    if key >= 1899 | key <= 1935 or key == 1962 or key ==1963 or key == 2007 or key ==2008 or key == 2010:
        try:
            dfs = pd.read_html(value)
            schedule = dfs[0]
            schedule.loc[:, 'Season'] = key
            schedules[df_name] = schedule
        except:
            continue
    else:
        try:
            dfs = pd.read_html(value)
            schedule = dfs[1]
            schedule.loc[:, 'Season'] = key
            schedules[df_name] = schedule
        except:
            continue

# %% [markdown]
# # Combine Dictionary of DataFrames using `pd.concat`

# %%
# create combined_schedule df
combined_schedule = pd.concat(schedules.values(), ignore_index=True)

# show df
combined_schedule
# Out:
#       G          Date  Day          School Unnamed: 4             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame        NaN       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame        NaN       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame          @              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame        NaN          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame          @             Michigan
# ..   ..           ...  ...             ...        ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame        NaN       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame        NaN  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame        NaN             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame        NaN          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame        NaN          (1) Alabama
#
#           Conf Unnamed: 7  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major          W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major          W   40    0   2  0  0.0    W 2                    NaN
# 2      Western          L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind          W   38    0   3  1  0.0    W 1                    NaN
# 4      Western          L    0   12   3  2  0.0    L 1                    NaN
# ..         ...        ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC        NaN   45   31   8  0  NaN    W 8                    NaN
# 969        ACC        NaN   31   17   9  0  NaN    W 9                    NaN
# 970        ACC        NaN   45   21  10  0  NaN   W 10                    NaN
# 971        ACC        NaN   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC        NaN   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time Unnamed: 5 Unnamed: 8
# 0      1899      NaN        NaN        NaN
# 1      1899      NaN        NaN        NaN
# 2      1899      NaN        NaN        NaN
# 3      1899      NaN        NaN        NaN
# 4      1899      NaN        NaN        NaN
# ..      ...      ...        ...        ...
# 968    2020  3:30 PM          @          W
# 969    2020  3:30 PM          @          W
# 970    2020  2:30 PM        NaN          W
# 971    2020  4:00 PM          N          L
# 972    2020  4:00 PM          N          L
#
# [973 rows x 19 columns]

# %% [markdown]
# # Data Cleaning/Wrangling

# %%
# rename columns
combined_schedule.rename(columns = {'Unnamed: 4': 'Location', 'Unnamed: 7': 'Result'}, inplace= True)

# show updated dataframe
combined_schedule
# Out:
#       G          Date  Day          School Location             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame      NaN       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame      NaN       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame        @              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame      NaN          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame        @             Michigan
# ..   ..           ...  ...             ...      ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame      NaN       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame      NaN  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame      NaN             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame      NaN          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame      NaN          (1) Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC    NaN   45   31   8  0  NaN    W 8                    NaN
# 969        ACC    NaN   31   17   9  0  NaN    W 9                    NaN
# 970        ACC    NaN   45   21  10  0  NaN   W 10                    NaN
# 971        ACC    NaN   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC    NaN   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time Unnamed: 5 Unnamed: 8
# 0      1899      NaN        NaN        NaN
# 1      1899      NaN        NaN        NaN
# 2      1899      NaN        NaN        NaN
# 3      1899      NaN        NaN        NaN
# 4      1899      NaN        NaN        NaN
# ..      ...      ...        ...        ...
# 968    2020  3:30 PM          @          W
# 969    2020  3:30 PM          @          W
# 970    2020  2:30 PM        NaN          W
# 971    2020  4:00 PM          N          L
# 972    2020  4:00 PM          N          L
#
# [973 rows x 19 columns]

# %%
# take non-null values from second Location column ('Unnamed: 5') and assign to cells in 'Location' column
combined_schedule["Location"] = np.where(combined_schedule["Unnamed: 5"].notnull(), combined_schedule["Unnamed: 5"], combined_schedule["Location"])

# take non-null values from second Result column ('Unnamed: 8') and assign to cells in 'Result' column
combined_schedule["Result"] = np.where(combined_schedule["Unnamed: 8"].notnull(), combined_schedule["Unnamed: 8"], combined_schedule["Result"])

# show updated dataframe
combined_schedule
# Out:
#       G          Date  Day          School Location             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame      NaN       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame      NaN       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame        @              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame      NaN          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame        @             Michigan
# ..   ..           ...  ...             ...      ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame        @       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame        @  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame      NaN             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame        N          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame        N          (1) Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC      W   45   31   8  0  NaN    W 8                    NaN
# 969        ACC      W   31   17   9  0  NaN    W 9                    NaN
# 970        ACC      W   45   21  10  0  NaN   W 10                    NaN
# 971        ACC      L   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC      L   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time Unnamed: 5 Unnamed: 8
# 0      1899      NaN        NaN        NaN
# 1      1899      NaN        NaN        NaN
# 2      1899      NaN        NaN        NaN
# 3      1899      NaN        NaN        NaN
# 4      1899      NaN        NaN        NaN
# ..      ...      ...        ...        ...
# 968    2020  3:30 PM          @          W
# 969    2020  3:30 PM          @          W
# 970    2020  2:30 PM        NaN          W
# 971    2020  4:00 PM          N          L
# 972    2020  4:00 PM          N          L
#
# [973 rows x 19 columns]

# %%
# remove second location column
del combined_schedule['Unnamed: 5']

# remove second result column
del combined_schedule['Unnamed: 8']

# show updated dataframe
combined_schedule
# Out:
#       G          Date  Day          School Location             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame      NaN       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame      NaN       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame        @              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame      NaN          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame        @             Michigan
# ..   ..           ...  ...             ...      ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame        @       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame        @  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame      NaN             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame        N          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame        N          (1) Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC      W   45   31   8  0  NaN    W 8                    NaN
# 969        ACC      W   31   17   9  0  NaN    W 9                    NaN
# 970        ACC      W   45   21  10  0  NaN   W 10                    NaN
# 971        ACC      L   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC      L   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time
# 0      1899      NaN
# 1      1899      NaN
# 2      1899      NaN
# 3      1899      NaN
# 4      1899      NaN
# ..      ...      ...
# 968    2020  3:30 PM
# 969    2020  3:30 PM
# 970    2020  2:30 PM
# 971    2020  4:00 PM
# 972    2020  4:00 PM
#
# [973 rows x 17 columns]

# %%
# replace @ symbols in Location column with 'Away' string
combined_schedule['Location'] = combined_schedule['Location'].str.replace("@", "Away")

# replace 'N' string in Location column with 'Neutral' string
combined_schedule['Location'] = combined_schedule['Location'].str.replace("N", "Neutral")

# replace NaN values in Location column with 'Home' string
combined_schedule['Location'] = combined_schedule['Location'].fillna("Home")

# show updated dataframe
combined_schedule
# Out:
#       G          Date  Day          School Location             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame     Home       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame     Home       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame     Away              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame     Home          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame     Away             Michigan
# ..   ..           ...  ...             ...      ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame     Away       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame     Away  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame     Home             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame  Neutral          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame  Neutral          (1) Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC      W   45   31   8  0  NaN    W 8                    NaN
# 969        ACC      W   31   17   9  0  NaN    W 9                    NaN
# 970        ACC      W   45   21  10  0  NaN   W 10                    NaN
# 971        ACC      L   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC      L   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time
# 0      1899      NaN
# 1      1899      NaN
# 2      1899      NaN
# 3      1899      NaN
# 4      1899      NaN
# ..      ...      ...
# 968    2020  3:30 PM
# 969    2020  3:30 PM
# 970    2020  2:30 PM
# 971    2020  4:00 PM
# 972    2020  4:00 PM
#
# [973 rows x 17 columns]

# %%
# create duplicate School column to standardize school name
combined_schedule['Standardized_School'] = combined_schedule['School']

# remove rankings from new column
combined_schedule['Standardized_School']= combined_schedule['Standardized_School'].str.replace(r'\d', '')
combined_schedule['Standardized_School']= combined_schedule['Standardized_School'].str.replace(r'[()]', '')

# show updated dataframe
combined_schedule
# Out:
# C:\Users\katie\AppData\Local\Temp/ipykernel_4528/3896399896.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   combined_schedule['Standardized_School']= combined_schedule['Standardized_School'].str.replace(r'\d', '')
# C:\Users\katie\AppData\Local\Temp/ipykernel_4528/3896399896.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   combined_schedule['Standardized_School']= combined_schedule['Standardized_School'].str.replace(r'[()]', '')
#       G          Date  Day          School Location             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame     Home       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame     Home       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame     Away              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame     Home          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame     Away             Michigan
# ..   ..           ...  ...             ...      ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame     Away       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame     Away  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame     Home             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame  Neutral          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame  Neutral          (1) Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC      W   45   31   8  0  NaN    W 8                    NaN
# 969        ACC      W   31   17   9  0  NaN    W 9                    NaN
# 970        ACC      W   45   21  10  0  NaN   W 10                    NaN
# 971        ACC      L   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC      L   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time Standardized_School
# 0      1899      NaN          Notre Dame
# 1      1899      NaN          Notre Dame
# 2      1899      NaN          Notre Dame
# 3      1899      NaN          Notre Dame
# 4      1899      NaN          Notre Dame
# ..      ...      ...                 ...
# 968    2020  3:30 PM          Notre Dame
# 969    2020  3:30 PM          Notre Dame
# 970    2020  2:30 PM          Notre Dame
# 971    2020  4:00 PM          Notre Dame
# 972    2020  4:00 PM          Notre Dame
#
# [973 rows x 18 columns]

# %%
# create duplicate Opponents column to standardize opponent name
combined_schedule['Standardized_Opponent'] = combined_schedule['Opponent']

# remove rankings from new column
combined_schedule['Standardized_Opponent']= combined_schedule['Standardized_Opponent'].str.replace(r'\d', '')
combined_schedule['Standardized_Opponent']= combined_schedule['Standardized_Opponent'].str.replace(r'[()]', '')

# show updated dataframe
combined_schedule
# Out:
# C:\Users\katie\AppData\Local\Temp/ipykernel_4528/3071907014.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   combined_schedule['Standardized_Opponent']= combined_schedule['Standardized_Opponent'].str.replace(r'\d', '')
# C:\Users\katie\AppData\Local\Temp/ipykernel_4528/3071907014.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   combined_schedule['Standardized_Opponent']= combined_schedule['Standardized_Opponent'].str.replace(r'[()]', '')
#       G          Date  Day          School Location             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame     Home       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame     Home       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame     Away              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame     Home          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame     Away             Michigan
# ..   ..           ...  ...             ...      ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame     Away       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame     Away  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame     Home             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame  Neutral          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame  Neutral          (1) Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC      W   45   31   8  0  NaN    W 8                    NaN
# 969        ACC      W   31   17   9  0  NaN    W 9                    NaN
# 970        ACC      W   45   21  10  0  NaN   W 10                    NaN
# 971        ACC      L   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC      L   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time Standardized_School Standardized_Opponent
# 0      1899      NaN          Notre Dame        Englewood High
# 1      1899      NaN          Notre Dame        Michigan State
# 2      1899      NaN          Notre Dame               Chicago
# 3      1899      NaN          Notre Dame           Lake Forest
# 4      1899      NaN          Notre Dame              Michigan
# ..      ...      ...                 ...                   ...
# 968    2020  3:30 PM          Notre Dame        Boston College
# 969    2020  3:30 PM          Notre Dame        North Carolina
# 970    2020  2:30 PM          Notre Dame              Syracuse
# 971    2020  4:00 PM          Notre Dame               Clemson
# 972    2020  4:00 PM          Notre Dame               Alabama
#
# [973 rows x 19 columns]

# %%
# create new column for converted datetime object
combined_schedule['Standardized_Date'] = pd.to_datetime(combined_schedule['Date'])

combined_schedule
# Out:
#       G          Date  Day          School Location             Opponent  \
# 0     1  Sep 27, 1899  Wed      Notre Dame     Home       Englewood High
# 1     2  Sep 30, 1899  Sat      Notre Dame     Home       Michigan State
# 2     3   Oct 4, 1899  Wed      Notre Dame     Away              Chicago
# 3     4  Oct 14, 1899  Sat      Notre Dame     Home          Lake Forest
# 4     5  Oct 18, 1899  Wed      Notre Dame     Away             Michigan
# ..   ..           ...  ...             ...      ...                  ...
# 968   8  Nov 14, 2020  Sat  (2) Notre Dame     Away       Boston College
# 969   9  Nov 27, 2020  Fri  (2) Notre Dame     Away  (25) North Carolina
# 970  10   Dec 5, 2020  Sat  (2) Notre Dame     Home             Syracuse
# 971  11  Dec 19, 2020  Sat  (2) Notre Dame  Neutral          (4) Clemson
# 972  12   Jan 1, 2021  Fri  (4) Notre Dame  Neutral          (1) Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes  \
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC      W   45   31   8  0  NaN    W 8                    NaN
# 969        ACC      W   31   17   9  0  NaN    W 9                    NaN
# 970        ACC      W   45   21  10  0  NaN   W 10                    NaN
# 971        ACC      L   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC      L   14   31  10  2  NaN    L 2              Rose Bowl
#
#      Season     Time Standardized_School Standardized_Opponent  \
# 0      1899      NaN          Notre Dame        Englewood High
# 1      1899      NaN          Notre Dame        Michigan State
# 2      1899      NaN          Notre Dame               Chicago
# 3      1899      NaN          Notre Dame           Lake Forest
# 4      1899      NaN          Notre Dame              Michigan
# ..      ...      ...                 ...                   ...
# 968    2020  3:30 PM          Notre Dame        Boston College
# 969    2020  3:30 PM          Notre Dame        North Carolina
# 970    2020  2:30 PM          Notre Dame              Syracuse
# 971    2020  4:00 PM          Notre Dame               Clemson
# 972    2020  4:00 PM          Notre Dame               Alabama
#
#     Standardized_Date
# 0          1899-09-27
# 1          1899-09-30
# 2          1899-10-04
# 3          1899-10-14
# 4          1899-10-18
# ..                ...
# 968        2020-11-14
# 969        2020-11-27
# 970        2020-12-05
# 971        2020-12-19
# 972        2021-01-01
#
# [973 rows x 20 columns]

# %%
combined_schedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   G                      973 non-null    int64
#  1   Date                   973 non-null    object
#  2   Day                    973 non-null    object
#  3   School                 973 non-null    object
#  4   Location               973 non-null    object
#  5   Opponent               973 non-null    object
#  6   Conf                   973 non-null    object
#  7   Result                 973 non-null    object
#  8   Pts                    973 non-null    int64
#  9   Opp                    973 non-null    int64
#  10  W                      973 non-null    int64
#  11  L                      973 non-null    int64
#  12  T                      662 non-null    float64
#  13  Streak                 973 non-null    object
#  14  Notes                  142 non-null    object
#  15  Season                 973 non-null    int64
#  16  Time                   88 non-null     object
#  17  Standardized_School    973 non-null    object
#  18  Standardized_Opponent  973 non-null    object
#  19  Standardized_Date      973 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(6), object(12)
# memory usage: 152.2+ KB

# %%
# list with desired column order
column_names = ['G', 'Season', 'Standardized_Date', 'Date', 'Day', 'Time', 'School', 'Standardized_School', 'Location', 'Opponent', 'Standardized_Opponent', 'Conf', 'Result', 'Pts', 'Opp', 'W', 'L', 'T', 'Streak', 'Notes']

# reorder columns
combined_schedule = combined_schedule.reindex(columns = column_names)

# show updated dataframe
combined_schedule
# Out:
#       G  Season Standardized_Date          Date  Day     Time          School  \
# 0     1    1899        1899-09-27  Sep 27, 1899  Wed      NaN      Notre Dame
# 1     2    1899        1899-09-30  Sep 30, 1899  Sat      NaN      Notre Dame
# 2     3    1899        1899-10-04   Oct 4, 1899  Wed      NaN      Notre Dame
# 3     4    1899        1899-10-14  Oct 14, 1899  Sat      NaN      Notre Dame
# 4     5    1899        1899-10-18  Oct 18, 1899  Wed      NaN      Notre Dame
# ..   ..     ...               ...           ...  ...      ...             ...
# 968   8    2020        2020-11-14  Nov 14, 2020  Sat  3:30 PM  (2) Notre Dame
# 969   9    2020        2020-11-27  Nov 27, 2020  Fri  3:30 PM  (2) Notre Dame
# 970  10    2020        2020-12-05   Dec 5, 2020  Sat  2:30 PM  (2) Notre Dame
# 971  11    2020        2020-12-19  Dec 19, 2020  Sat  4:00 PM  (2) Notre Dame
# 972  12    2020        2021-01-01   Jan 1, 2021  Fri  4:00 PM  (4) Notre Dame
#
#     Standardized_School Location             Opponent Standardized_Opponent  \
# 0            Notre Dame     Home       Englewood High        Englewood High
# 1            Notre Dame     Home       Michigan State        Michigan State
# 2            Notre Dame     Away              Chicago               Chicago
# 3            Notre Dame     Home          Lake Forest           Lake Forest
# 4            Notre Dame     Away             Michigan              Michigan
# ..                  ...      ...                  ...                   ...
# 968          Notre Dame     Away       Boston College        Boston College
# 969          Notre Dame     Away  (25) North Carolina        North Carolina
# 970          Notre Dame     Home             Syracuse              Syracuse
# 971          Notre Dame  Neutral          (4) Clemson               Clemson
# 972          Notre Dame  Neutral          (1) Alabama               Alabama
#
#           Conf Result  Pts  Opp   W  L    T Streak                  Notes
# 0    Non-Major      W   29    5   1  0  0.0    W 1                    NaN
# 1    Non-Major      W   40    0   2  0  0.0    W 2                    NaN
# 2      Western      L    6   23   2  1  0.0    L 1                    NaN
# 3          Ind      W   38    0   3  1  0.0    W 1                    NaN
# 4      Western      L    0   12   3  2  0.0    L 1                    NaN
# ..         ...    ...  ...  ...  .. ..  ...    ...                    ...
# 968        ACC      W   45   31   8  0  NaN    W 8                    NaN
# 969        ACC      W   31   17   9  0  NaN    W 9                    NaN
# 970        ACC      W   45   21  10  0  NaN   W 10                    NaN
# 971        ACC      L   10   34  10  1  NaN    L 1  ACC Championship Game
# 972        SEC      L   14   31  10  2  NaN    L 2              Rose Bowl
#
# [973 rows x 20 columns]

# %% [markdown]
# # Write DataFrame to CSV File

# %%
# write combined_schedules dataframe to csv file
combined_schedule.to_csv('combined_nd_schedules.csv', index=False)
